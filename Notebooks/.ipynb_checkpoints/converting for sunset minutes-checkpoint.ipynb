# %%
import pandas as pd
import numpy as np

import scipy
import statsmodels.formula.api as smf
import statistics as st 
import pandas as pd
import matplotlib.pyplot as plt

import requests
from geopy.geocoders import Nominatim
from astral import LocationInfo
import datetime
from astral.sun import sun
from astral import LocationInfo

from time import time

# %%
cd
# Out:
# /Users/karatechop

# %%
cd /Users/karatechop/Documents/GitHub/senior-thesis-pretextual-stops/Data/RIPA-DATA-CA-as-of-2022\ \(CSV\)
# Out:
# /Users/karatechop/Documents/GitHub/senior-thesis-pretextual-stops/Data/RIPA-DATA-CA-as-of-2022 (CSV)

# %%
working_main = pd.read_csv('working_main.csv')
print(working_main.columns,'\n',working_main.shape,'\n',len(working_main.time))
# Out:
# Index(['date', 'time', 'sex', 'race', 'type', 'duration', 'city'], dtype='object')
#  (2463454, 7)
#  2463454

# %%
time = []
for i in range(len(working_main['time'])): 
    current = working_main.loc[i,'time']
    
    if len(working_main.loc[i,'time']) < 8:
        time.append(current + ':00')
    elif len(working_main.loc[i,'time']) > 8:
        time.append(current[11:19])
    else:
        time.append(current)
        
working_main['time'] = time
working_main['time'] = pd.to_datetime(working_main['time'],format="%H:%M:%S")
print('len of time column is:',len(working_main.time),'\n sum of null time values is:',working_main['time'].isna().sum())
working_main
# Out:
# len of time column is: 2463454
#  sum of null time values is: 0
#                date                time     sex                    race  \
# 0        12/09/2021 1900-01-01 13:00:00    Male      hispanic/latino(a)
# 1          04/26/21 1900-01-01 23:00:00    Male  black/african american
# 2          04/15/21 1900-01-01 11:35:00  Female  black/african american
# 3          04/01/21 1900-01-01 01:53:00    Male                   asian
# 4        12/20/2021 1900-01-01 16:07:00  Female                   white
# ...             ...                 ...     ...                     ...
# 2463449  11/02/2021 1900-01-01 00:19:00  Female      hispanic/latino(a)
# 2463450  11/02/2021 1900-01-01 00:14:00    Male      hispanic/latino(a)
# 2463451  11/01/2021 1900-01-01 01:00:00    Male      hispanic/latino(a)
# 2463452  11/01/2021 1900-01-01 01:00:00    Male      hispanic/latino(a)
# 2463453  11/01/2021 1900-01-01 01:00:00    Male      hispanic/latino(a)
#
#                type  duration            city
# 0        Non-Moving       5.0  ALL-SJPD-AB953
# 1               NaN      60.0  ALL-SJPD-AB953
# 2         Equipment      10.0  ALL-SJPD-AB953
# 3        Non-Moving     100.0  ALL-SJPD-AB953
# 4               NaN      10.0  ALL-SJPD-AB953
# ...             ...       ...             ...
# 2463449  Non-Moving      74.0  ALL-LAPD-AB953
# 2463450  Non-Moving      81.0  ALL-LAPD-AB953
# 2463451         NaN      13.0  ALL-LAPD-AB953
# 2463452  Non-Moving      13.0  ALL-LAPD-AB953
# 2463453  Non-Moving      13.0  ALL-LAPD-AB953
#
# [2463454 rows x 7 columns]

# %%
working_main['city'].isna().sum()
# Out:
# 0

# %%
working_main.rename(columns={'city':'agency'},inplace=True)

def city_from_agency_check(df):
    city_str = []
    lat_str = []
    lon_str = []
    wave_str = []
    
    for i in df['agency']:
        if 'ALL-SJPD-AB953' in i:
            city_str.append('San Jose')
            lat_str.append(37.3387)
            lon_str.append(-121.8853)
            wave_str.append(2)
        elif 'ALL-LBPD-AB953' in i:
            city_str.append('Long Beach')
            lat_str.append(33.7701)
            lon_str.append(-118.1937)
            wave_str.append(2)
        elif 'ALL-OAKLAND_PD-AB953' in i:
            city_str.append('Oakland')
            lat_str.append(37.8044)
            lon_str.append(-122.2712)
            wave_str.append(2)
        elif 'Berkeley PD' in i:
            city_str.append('Berkeley')
            lat_str.append(37.8715)
            lon_str.append(-122.2730)
            wave_str.append(3)
        elif 'ALL-MARIN-AB953' in i:
            city_str.append('Marin')
            lat_str.append(38.0834)
            lon_str.append(-122.7633)
            wave_str.append(3)
        elif 'Davis PD' in i:
            city_str.append('Davis')
            lat_str.append(38.5449)
            lon_str.append(-121.7405)
            wave_str.append(3)
        elif 'ALL-RIVERSIDE-AB953' in i:
            city_str.append('Riverside')
            lat_str.append(33.9806)
            lon_str.append(-117.3755)
            wave_str.append(1)
        elif 'SDPD' in i:
            city_str.append('San Diego')
            lat_str.append(32.7157)
            lon_str.append(-117.1611)
            wave_str.append(1)
        elif 'ALL-SFPD-AB953' in i:
            city_str.append('San Francisco')
            lat_str.append(37.7749)
            lon_str.append(-122.4194)
            wave_str.append(1)
        elif 'ALL-LAPD-AB953' in i:
            city_str.append('Los Angeles')
            lat_str.append(34.0522)
            lon_str.append(-118.2437)
            wave_str.append(1)
        
    df['city']=city_str
    df['lat']=lat_str
    df['lon']=lon_str
    df['wave']=wave_str
    
    pd.option_context('display.precision', 10)
    
    return df

working_main = city_from_agency_check(working_main)
working_main
# Out:
#                date                time     sex                    race  \
# 0        12/09/2021 1900-01-01 13:00:00    Male      hispanic/latino(a)
# 1          04/26/21 1900-01-01 23:00:00    Male  black/african american
# 2          04/15/21 1900-01-01 11:35:00  Female  black/african american
# 3          04/01/21 1900-01-01 01:53:00    Male                   asian
# 4        12/20/2021 1900-01-01 16:07:00  Female                   white
# ...             ...                 ...     ...                     ...
# 2463449  11/02/2021 1900-01-01 00:19:00  Female      hispanic/latino(a)
# 2463450  11/02/2021 1900-01-01 00:14:00    Male      hispanic/latino(a)
# 2463451  11/01/2021 1900-01-01 01:00:00    Male      hispanic/latino(a)
# 2463452  11/01/2021 1900-01-01 01:00:00    Male      hispanic/latino(a)
# 2463453  11/01/2021 1900-01-01 01:00:00    Male      hispanic/latino(a)
#
#                type  duration          agency         city      lat       lon  \
# 0        Non-Moving       5.0  ALL-SJPD-AB953     San Jose  37.3387 -121.8853
# 1               NaN      60.0  ALL-SJPD-AB953     San Jose  37.3387 -121.8853
# 2         Equipment      10.0  ALL-SJPD-AB953     San Jose  37.3387 -121.8853
# 3        Non-Moving     100.0  ALL-SJPD-AB953     San Jose  37.3387 -121.8853
# 4               NaN      10.0  ALL-SJPD-AB953     San Jose  37.3387 -121.8853
# ...             ...       ...             ...          ...      ...       ...
# 2463449  Non-Moving      74.0  ALL-LAPD-AB953  Los Angeles  34.0522 -118.2437
# 2463450  Non-Moving      81.0  ALL-LAPD-AB953  Los Angeles  34.0522 -118.2437
# 2463451         NaN      13.0  ALL-LAPD-AB953  Los Angeles  34.0522 -118.2437
# 2463452  Non-Moving      13.0  ALL-LAPD-AB953  Los Angeles  34.0522 -118.2437
# 2463453  Non-Moving      13.0  ALL-LAPD-AB953  Los Angeles  34.0522 -118.2437
#
#          wave
# 0           2
# 1           2
# 2           2
# 3           2
# 4           2
# ...       ...
# 2463449     1
# 2463450     1
# 2463451     1
# 2463452     1
# 2463453     1
#
# [2463454 rows x 11 columns]

# %%
working_main.agency.value_counts()
# Out:
# ALL-LAPD-AB953          1602977
# ALL-RIVERSIDE-AB953      314497
# SDPD                     246655
# ALL-SFPD-AB953           130977
# ALL-OAKLAND_PD-AB953      68527
# ALL-SJPD-AB953            50443
# ALL-LBPD-AB953            36670
# Berkeley PD                6466
# ALL-MARIN-AB953            4746
# Davis PD                   1496
# Name: agency, dtype: int64

# %%
# working_main.to_csv('working_main_expanded.csv')

# %%
working_main_expanded = working_main

# %%
# working_main_expanded = pd.read_csv('working_main_expanded.csv')

# %%
working_main_expanded.date = pd.to_datetime(working_main_expanded.date)

# %%
working_main_expanded.dtypes
# Out:
# date                object
# time        datetime64[ns]
# sex                 object
# race                object
# type                object
# duration           float64
# agency              object
# city                object
# lat                float64
# lon                float64
# wave                 int64
# dtype: object

# %%
# %%timeit
# start = time()

sunset_list = []
counter = 0



for i in working_main_expanded['date']:
    year = i.year
    month = i.month
    day = i.day

    name = working_main_expanded['city'][counter]
    lat = working_main_expanded['lat'][counter]
    lon = working_main_expanded['lon'][counter]

    loc = LocationInfo(name=name, region='CA, USA', timezone='America/Los_Angeles', #https://en.wikipedia.org/wiki/List_of_tz_database_time_zones
                       latitude=lat, longitude=lon)
    


    s = sun(loc.observer, date=datetime.date(year, month, day), tzinfo=loc.timezone)
    for key in ['sunset']:
        sunset_list.append(s[key].time())
        
    counter+=1
    
sunset_list2 = [str(i)[:8] for i in sunset_list]  
working_main_expanded['sunsettime'] = sunset_list2
# print(f'that whole process took {(time()-start)/60} minutes')
# sunset_list

# %%
date_to_subtract = datetime.datetime(1900, 1, 1)

working_main_expanded['mins_sunset'] = [round(((datetime.datetime.strptime(i, '%H:%M:%S') - date_to_subtract).total_seconds() / 60.0),0) 
                                           for i in sunset_list2]
working_main_expanded['mins_stop_time'] = [round(((i - date_to_subtract).total_seconds()/60),0) 
                                           for i in working_main_expanded['time']]
working_main_expanded['time_until_sunset'] = working_main_expanded['mins_stop_time'] - working_main_expanded['mins_sunset']

working_main_expanded.head(5)
# Out:
#                   date                time     sex                    race  \
# 0  2021-12-09 00:00:00 1900-01-01 13:00:00    Male      hispanic/latino(a)
# 1  2021-04-26 00:00:00 1900-01-01 23:00:00    Male  black/african american
# 2  2021-04-15 00:00:00 1900-01-01 11:35:00  Female  black/african american
# 3  2021-04-01 00:00:00 1900-01-01 01:53:00    Male                   asian
# 4  2021-12-20 00:00:00 1900-01-01 16:07:00  Female                   white
#
#          type  duration          agency      city      lat       lon  wave  \
# 0  Non-Moving       5.0  ALL-SJPD-AB953  San Jose  37.3387 -121.8853     2
# 1         NaN      60.0  ALL-SJPD-AB953  San Jose  37.3387 -121.8853     2
# 2   Equipment      10.0  ALL-SJPD-AB953  San Jose  37.3387 -121.8853     2
# 3  Non-Moving     100.0  ALL-SJPD-AB953  San Jose  37.3387 -121.8853     2
# 4         NaN      10.0  ALL-SJPD-AB953  San Jose  37.3387 -121.8853     2
#
#         sunsettime  mins_sunset  mins_stop_time  time_until_sunset
# 0  16:49:31.773951       1010.0           780.0             -230.0
# 1  19:52:49.407756       1193.0          1380.0              187.0
# 2  19:42:53.265865       1183.0           695.0             -488.0
# 3  19:30:20.397843       1170.0           113.0            -1057.0
# 4  16:52:49.858145       1013.0           967.0              -46.0

# %%
date_to_subtract = datetime.datetime(1900, 1, 1)

# working_main['totalminutes_stop_time'] = [((i - date_to_subtract).total_seconds()/60) for i in working_main_expanded['time']]
# dog = [((i - date_to_subtract).total_seconds()/60) for i in working_main_expanded['sunsettime']]
# working_main['time_to_sunset'] = working_main['totalminutes_sunsettime'] - working_main['totalminutes_stop_time']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [268], in <cell line: 4>()
#       1 date_to_subtract = datetime.datetime(1900, 1, 1)
#       3 # working_main['totalminutes_stop_time'] = [((i - date_to_subtract).total_seconds()/60) for i in working_main_expanded['time']]
# ----> 4 dog = [((i - date_to_subtract).total_seconds()/60) for i in working_main_expanded['sunsettime']]
#
# Input In [268], in <listcomp>(.0)
#       1 date_to_subtract = datetime.datetime(1900, 1, 1)
#       3 # working_main['totalminutes_stop_time'] = [((i - date_to_subtract).total_seconds()/60) for i in working_main_expanded['time']]
# ----> 4 dog = [((i - date_to_subtract).total_seconds()/60) for i in working_main_expanded['sunsettime']]
#
# File ~/opt/anaconda3/envs/VOD-RIPA/lib/python3.10/site-packages/pandas/core/arrays/datetimes.py:640, in DatetimeArray.__iter__(self)
#     638 start_i = i * chunksize
#     639 end_i = min((i + 1) * chunksize, length)
# --> 640 converted = ints_to_pydatetime(
#     641     data[start_i:end_i], tz=self.tz, freq=self.freq, box="timestamp"
#     642 )
#     643 yield from converted
#
# File ~/opt/anaconda3/envs/VOD-RIPA/lib/python3.10/site-packages/pandas/_libs/tslibs/vectorized.pyx:158, in pandas._libs.tslibs.vectorized.ints_to_pydatetime()
#
# File ~/opt/anaconda3/envs/VOD-RIPA/lib/python3.10/site-packages/pandas/_libs/tslibs/timezones.pyx:266, in pandas._libs.tslibs.timezones.get_dst_info()
#
# AttributeError: 'NoneType' object has no attribute 'total_seconds'

# %%
# import json
# data = {}
# counter = 0 

# for i in sunset_list:
#     data[counter] = str(i)
#     counter += 1
    
# with open('data.json', 'w', encoding='utf-8') as f:
#     json.dump(data, f, ensure_ascii=False, indent=4)

# %%
cols = ['date', 'time', 'sex', 'race', 'type', 'duration', 'agency', 'city',
       'lat', 'lon', 'wave', 'sunsettime','mins_stop_time','mins_sunset','mins_until_sunset']
working_main_expanded = working_main_expanded[cols]
working_main_expanded
# Out:
#                         date                time     sex  \
# 0        2021-12-09 00:00:00 1900-01-01 13:00:00    Male
# 1        2021-04-26 00:00:00 1900-01-01 23:00:00    Male
# 2        2021-04-15 00:00:00 1900-01-01 11:35:00  Female
# 3        2021-04-01 00:00:00 1900-01-01 01:53:00    Male
# 4        2021-12-20 00:00:00 1900-01-01 16:07:00  Female
# ...                      ...                 ...     ...
# 2463449  2021-11-02 00:00:00 1900-01-01 00:19:00  Female
# 2463450  2021-11-02 00:00:00 1900-01-01 00:14:00    Male
# 2463451  2021-11-01 00:00:00 1900-01-01 01:00:00    Male
# 2463452  2021-11-01 00:00:00 1900-01-01 01:00:00    Male
# 2463453  2021-11-01 00:00:00 1900-01-01 01:00:00    Male
#
#                            race        type  duration          agency  \
# 0            hispanic/latino(a)  Non-Moving       5.0  ALL-SJPD-AB953
# 1        black/african american         NaN      60.0  ALL-SJPD-AB953
# 2        black/african american   Equipment      10.0  ALL-SJPD-AB953
# 3                         asian  Non-Moving     100.0  ALL-SJPD-AB953
# 4                         white         NaN      10.0  ALL-SJPD-AB953
# ...                         ...         ...       ...             ...
# 2463449      hispanic/latino(a)  Non-Moving      74.0  ALL-LAPD-AB953
# 2463450      hispanic/latino(a)  Non-Moving      81.0  ALL-LAPD-AB953
# 2463451      hispanic/latino(a)         NaN      13.0  ALL-LAPD-AB953
# 2463452      hispanic/latino(a)  Non-Moving      13.0  ALL-LAPD-AB953
# 2463453      hispanic/latino(a)  Non-Moving      13.0  ALL-LAPD-AB953
#
#                 city      lat       lon  wave       sunsettime  \
# 0           San Jose  37.3387 -121.8853     2  16:49:31.773951
# 1           San Jose  37.3387 -121.8853     2  19:52:49.407756
# 2           San Jose  37.3387 -121.8853     2  19:42:53.265865
# 3           San Jose  37.3387 -121.8853     2  19:30:20.397843
# 4           San Jose  37.3387 -121.8853     2  16:52:49.858145
# ...              ...      ...       ...   ...              ...
# 2463449  Los Angeles  34.0522 -118.2437     1  17:58:32.856081
# 2463450  Los Angeles  34.0522 -118.2437     1  17:58:32.856081
# 2463451  Los Angeles  34.0522 -118.2437     1  17:59:28.252884
# 2463452  Los Angeles  34.0522 -118.2437     1  17:59:28.252884
# 2463453  Los Angeles  34.0522 -118.2437     1  17:59:28.252884
#
#          mins_stop_time  mins_sunset  mins_until_sunset
# 0                 780.0       1010.0             -230.0
# 1                1380.0       1193.0              187.0
# 2                 695.0       1183.0             -488.0
# 3                 113.0       1170.0            -1057.0
# 4                 967.0       1013.0              -46.0
# ...                 ...          ...                ...
# 2463449            19.0       1079.0            -1060.0
# 2463450            14.0       1079.0            -1065.0
# 2463451            60.0       1079.0            -1019.0
# 2463452            60.0       1079.0            -1019.0
# 2463453            60.0       1079.0            -1019.0
#
# [2463454 rows x 15 columns]

# %%
working_main_expanded.to_csv('working_main_expanded.csv',index=False)
