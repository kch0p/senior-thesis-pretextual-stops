# %%
import pandas as pd
import numpy as np
from time import time

# %%
cd
# Out:
# /Users/karatechop

# %%
cd /Users/karatechop/Documents/GitHub/senior-thesis-pretextual-stops/Data/RIPA-DATA-CA-as-of-2022\ \(CSV\)
# Out:
# /Users/karatechop/Documents/GitHub/senior-thesis-pretextual-stops/Data/RIPA-DATA-CA-as-of-2022 (CSV)

# %%
pd.read_csv('la_lat_lon_expanded.csv')

# %%
cd
# Out:
# /Users/karatechop

# %%
cd /Users/karatechop/Documents/GitHub/senior-thesis-pretextual-stops/Data/RIPA-DATA-CA-as-of-2022 (CSV)/Wave 1/LAPD
# Out:
# /Users/karatechop/Documents/GitHub/senior-thesis-pretextual-stops/Data/RIPA-DATA-CA-as-of-2022 (CSV)/Wave 1/LAPD

# %%
pd.read_csv('ALL-LAPD-AB953.csv')
# Out:
#                Date   time  Duration  Experience      PID  \
# 0        07/01/2018  00:02        10           0    25367
# 1        07/01/2018  21:50       180           0    25405
# 2        07/01/2018  21:50       180           0    25406
# 3        07/01/2018  00:16        15           0    25412
# 4        07/01/2018  00:16        15           0    25413
# ...             ...    ...       ...         ...      ...
# 1602972  11/02/2021  00:19        74           0  2078393
# 1602973  11/02/2021  00:14        81           0  2078394
# 1602974  11/01/2021  01:00        13           0  2078424
# 1602975  11/01/2021  01:00        13           0  2078428
# 1602976  11/01/2021  01:00        13           0  2078432
#
#                                   race  sex  age          type  reason basis  \
# 0               black/african american  1.0   32   2 Equipment       1   NaN
# 1        middle eastern or south asian  1.0   24  3 Non-Moving       1   NaN
# 2        middle eastern or south asian  1.0   30  3 Non-Moving       1   NaN
# 3                                white  2.0   45           NaN       2     1
# 4                   hispanic/latino(a)  1.0   30           NaN       2     1
# ...                                ...  ...  ...           ...     ...   ...
# 1602972             hispanic/latino(a)  2.0   25  3 Non-Moving       1   NaN
# 1602973             hispanic/latino(a)  1.0   30  3 Non-Moving       1   NaN
# 1602974             hispanic/latino(a)  1.0   25      1 Moving       1   NaN
# 1602975             hispanic/latino(a)  1.0   25  3 Non-Moving       1   NaN
# 1602976             hispanic/latino(a)  1.0   18  3 Non-Moving       1   NaN
#
#                                actions taken search basis seizure basis  \
# 0                     "18,na","20,na","1,na"            1           NaN
# 1                                     "5,na"          NaN           NaN
# 2                                     "5,na"          NaN           NaN
# 3                                    "24,na"          NaN           NaN
# 4                                    "18,na"            1           NaN
# ...                                      ...          ...           ...
# 1602972                               "1,na"          NaN           NaN
# 1602973         "17,Y","18,na","1,na","4,na"            1           NaN
# 1602974                        "1,na","4,na"          NaN           NaN
# 1602975  "17,Y","18,na","1,na","4,na","5,na"          1,4           NaN
# 1602976  "17,Y","18,na","1,na","4,na","5,na"            1           NaN
#
#         property seized evidence result                   location
# 0                   NaN        1      7           E CENTURY & MAIN
# 1                   NaN        1      5    Vine St & W Sunset Blvd
# 2                   NaN        1      5    Vine St & W Sunset Blvd
# 3                   NaN        1      7  LOUISE Ave & VICTORY Blvd
# 4                   NaN        1      7  LOUISE Ave & VICTORY Blvd
# ...                 ...      ...    ...                        ...
# 1602972             NaN        1      1      S Main St & E 17th St
# 1602973             NaN        1      2    S Santee St & E 16th St
# 1602974             NaN        1      2   Avalon Blvd & E Mlk Blvd
# 1602975             NaN        1      1   Avalon Blvd & E Mlk Blvd
# 1602976             NaN        1      1   Avalon Blvd & E Mlk Blvd
#
# [1602977 rows x 18 columns]
