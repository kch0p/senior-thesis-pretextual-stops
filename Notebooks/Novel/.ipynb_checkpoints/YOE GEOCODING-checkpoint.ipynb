# %%
import pandas as pd
import numpy as np

from time import time
from string import digits
import random
import threading

from geopy import Point
from geopy import Nominatim
from postal.parser import parse_address
from postal.expand import expand_address
import googlemaps
import warnings
# from googlemaps_api_key import key 

# key = key.replace('†','')
key = ''
gmaps = googlemaps.Client(key=key)
# https://console.cloud.google.com/apis/credentials?project=la-api-key
# Out:
#  API queries_quota: 60

# %%
cd
# Out:
# /Users/karatechop

# %%
cd /Users/karatechop/Documents/GitHub/senior-thesis-pretextual-stops/Data/Formatted with YOE
# Out:
# /Users/karatechop/Documents/GitHub/senior-thesis-pretextual-stops/Data/Formatted with YOE

# %%
ls
# Out:
# ALL-BPD-AB953-DUSK.csv      ALL-OAKLAND_PD-AB953.csv
# ALL-BPD-AB953.csv           ALL-SDPD-AB953-DUSK.csv
# ALL-MARIN-AB953-DUSK.csv    ALL-SDPD-AB953.csv
# ALL-MARIN-AB953.csv         ALL-SFPD-AB953-DUSK.csv
# ALL-OAKLAND-AB953-DUSK.csv  ALL-SFPD-AB953.csv

# %% [raw]
# SFPD: 26k unique intersections, 67k stops
# SDPD: 126 beats, 105K stops
# OAK: 58 beats, 7.5k stops
# BPD: 2800 coordinate pairs 2.9k stops
# MARIN: 2200 similar addresses, 2.8k stops

# %% [markdown]
# ## Function Setup

# %%
# def find_lat_lon_GMV3_debuggARR(city,address):
#     bounds = gmaps.geocode(city)[0]['geometry']['bounds']
    
#     if address != None: 
#         try:
#             return gmaps.geocode(address,bounds=bounds)

#         except:
#             print(f'Google maps failed for {address}')
          
#             pass

# %%
def find_lat_lon_GMV3(city,df,location_col='location'):
    df['neighborhood'],df['zip'],df['coords'] = None,None,None
    gmv3_total_start = time()
    counter = 0
    
    global failed_addresses, failed_counter
    failed_addresses = []
    failed_counter = 0
    
    bounds = gmaps.geocode(city)[0]['geometry']['bounds']
    
    for address in df[location_col].unique(): 
        if address != None and 'freeway' not in address: 
            try:
                result = gmaps.geocode(address,bounds=bounds)
                
                df.loc[df[location_col]==address,'gmap address'] = result[0]['formatted_address']
                df.loc[df[location_col]==address,'neighborhood'] = result[0]['address_components'][1]['long_name']
                df.loc[df[location_col]==address,'zip'] = result[0]['address_components'][-1]['long_name']
                df.loc[df[location_col]==address,'coords'] = str(result[0]['geometry']['location']['lat']) + ', ' +\
                                                             str(result[0]['geometry']['location']['lng'])
            
            except:
#                 print(f'Google maps failed for {address}')
                
                failed_addresses.append(address)
                failed_counter+=1
                
                pass
        
        
        counter+=1
        if counter%500==0:
            time_passed = round((time()-gmv3_total_start)/60,2)
            print(f'Counter is at {counter} for {city}. {time_passed} minutes have passed.')

# %% [markdown]
# ## WAVE 1

# %%
SFPD = pd.read_csv('ALL-SFPD-AB953-DUSK.csv')
SFPD = SFPD[SFPD['itp']==1]

SFPD = SFPD.sort_values(by='location')
SFPD['location'] = SFPD['location'].str.lower()
SFPD.loc[SFPD['location'].str.contains('101'),'location'] = '101 freeway'

SFPD.shape
# Out:
# (24107, 14)

# %%
SFPD1 = SFPD.iloc[:int(SFPD.shape[0]/3),:]
SFPD2 = SFPD.iloc[int(SFPD.shape[0]/3):int(SFPD.shape[0]/3)*2,:]
SFPD3 = SFPD.iloc[int(SFPD.shape[0]/3)*2:int(SFPD.shape[0]/3)*3,:]

# %%
len(SFPD['location'].unique())
# Out:
# 12151

# %%
# find_lat_lon_GMV3('San Francisco',SFPD,'location')
SFPD.sample(5)
# Out:
# Google maps failed for N/A..
# Google maps failed for PENNSYLVANIA AVE & MARIPOSA ST
# Google maps failed for Trillium CNG Lot

# %%
warnings.filterwarnings("ignore") 

if __name__ =="__main__":
    t1 = threading.Thread(target=find_lat_lon_GMV3,args=('SAN FRANCISCO',SFPD1))
    t2 = threading.Thread(target=find_lat_lon_GMV3,args=('SAN FRANCISCO',SFPD2))
    t3 = threading.Thread(target=find_lat_lon_GMV3,args=('SAN FRANCISCO',SFPD3))
    
    t1.start()
    t2.start()
    t3.start()
 
    t1.join()
    t2.join()
    t3.join()
 
    # both threads completely executed
    print("\n\n\nBoth threads are done!\n\n")
# Out:
# Counter is at 500 for SAN FRANCISCO. 1.01 minutes have passed.
# Counter is at 500 for SAN FRANCISCO. 1.01 minutes have passed.
# Counter is at 500 for SAN FRANCISCO. 1.01 minutes have passed.
# Counter is at 1000 for SAN FRANCISCO. 2.1 minutes have passed.
# Counter is at 1000 for SAN FRANCISCO. 2.14 minutes have passed.
# Counter is at 1000 for SAN FRANCISCO. 2.16 minutes have passed.
# Counter is at 1500 for SAN FRANCISCO. 3.15 minutes have passed.
# Counter is at 1500 for SAN FRANCISCO. 3.24 minutes have passed.
# Counter is at 1500 for SAN FRANCISCO. 3.24 minutes have passed.
# Counter is at 2000 for SAN FRANCISCO. 4.23 minutes have passed.
# Counter is at 2000 for SAN FRANCISCO. 4.26 minutes have passed.
# Counter is at 2000 for SAN FRANCISCO. 4.3 minutes have passed.
# Counter is at 2500 for SAN FRANCISCO. 5.27 minutes have passed.
# Counter is at 2500 for SAN FRANCISCO. 5.34 minutes have passed.
# Counter is at 2500 for SAN FRANCISCO. 5.38 minutes have passed.
# Counter is at 3000 for SAN FRANCISCO. 6.32 minutes have passed.
# Counter is at 3000 for SAN FRANCISCO. 6.33 minutes have passed.
# Counter is at 3000 for SAN FRANCISCO. 6.5 minutes have passed.
# Counter is at 3500 for SAN FRANCISCO. 7.38 minutes have passed.
# Counter is at 3500 for SAN FRANCISCO. 7.4 minutes have passed.
# Counter is at 3500 for SAN FRANCISCO. 7.53 minutes have passed.
# Counter is at 4000 for SAN FRANCISCO. 8.49 minutes have passed.
#
#
#
# Both threads are done!

# %%
SFPD_converted = pd.concat([SFPD1,SFPD2,SFPD3])
SFPD_converted.isna().sum()
# Out:
# date                   0
# time                   0
# Experience             0
# race                   0
# type                  29
# location               0
# sunsettime             0
# dusktime               0
# mins_sunset            0
# mins_dusk              0
# mins_stop_time         0
# mins_before_dusk       0
# itp                    0
# dark                   0
# neighborhood        1952
# zip                 1952
# coords              1952
# gmap address        1946
# dtype: int64

# %%
def formatter(address):
    address = address.replace('/',' & ')
    address = address.replace(' / ',' & ')
    address = address.replace('/ ',' & ')
    address = address.replace(' @ ',' & ')
    address = address.replace(' and ',' & ')
    
    if 'terminal' in address:
        address = 'SFO'
    if 'upper' in address or 'lower' in address or 'sfia' in address:
        address = 'SFO'
    
    if address.split()[-1].isalpha:
        address += 'th'
        
    return address

# %%
# Out:
# ['columbus/washington',
#  'congdon/silver',
#  '00 block of grove street',
#  '00 block of  cervantes',
#  'courtyard 3',
#  '00 block of 4th street',
#  '000 blk 7th st.',
#  'cple  /  wallwr',
#  '000 blk of 7th st.',
#  'crescent/presita',
#  'curtis/morse',
#  '02nd st / south park',
#  'oakdale and griffith',
#  'oakdale/baldwin',
#  'octavia @ oak',
#  'octavia and grove',
#  'octavia and laguna',
#  'octavia and bay',
#  'on 02/12/2019 i conducted a traffic stop because the drivers registration tabs were not present on the vehicle.',
#  'driving without headlights during',
#  '07th st / cleveland st',
#  'departure level itb door #4',
#  'departure level itb door #5',
#  'departure level terminal 3 center island',
#  'dimond / kern',
#  'disobeying a sign',
#  '09th st / division st',
#  'division and isis',
#  '100 4th street',
#  '100 5th street',
#  'dolores and guerrero',
#  '100 block of brookdale',
#  'dolores/25th st',
#  'pennsylvania ave / 25th st',
#  'domestic lower level t2',
#  '100 block jefferson',
#  'driver drove through a red light when the muni train light turned white.',
#  'driver made an illegal right turn. no right turn sign is posted.',
#  'driving in a marked transit lane',
#  '100 block of  hyde',
#  '100 block of topaz dr',
#  'duncan/church',
#  'e/b 80 off ramp to ti',
#  '100 block of williams',
#  'e/b ocean just pass the 280 northbound entrance',
#  '100 block of everson',
#  '1000 blk of mission',
#  '1000 blk. of mission',
#  '1000 block hyde',
#  '1000 block of howard',
#  '1000 block of mission',
#  '1000 block of fillmore',
#  '10th av/lincoln wy',
#  'end of irnwood at fairfax',
#  '10th st. corridor',
#  '10th harrison',
#  '10th/ lincoln',
#  '10th/division',
#  'eastbound frederick street does not come to a complete full stop behind the limit line at willard street.',
#  '1100 block of fillmore',
#  '1100 block of mission',
#  '1100 block of market',
#  'embarcadero st / bryant st',
#  'prohibited left turn',
#  'pacheco@47th',
#  'pacific / powell',
#  '11th/ jesse',
#  '11th/division st',
#  '1200 block market',
#  '1200 block of fell',
#  'essex f',
#  '1200 block mission',
#  'essex harrison',
#  'euclid @ spruce',
#  'parker/euclid',
#  'parker/geary',
#  'passenger threw trash out of window',
#  'persia',
#  'euclid/ heather',
#  'euclid/collins',
#  'euclid/iris',
#  'euclid/laurel',
#  'euclid/manzanita',
#  'euclid/parker',
#  'euclid/spruce',
#  'person went through an intersection where you are only allowed to turn right. person did not obey the sign posted.',
#  'phelps/la salle',
#  'expired reg',
#  'fail to stop at stop sign',
#  '1300 block of webster',
#  'failure to comply with permit terms',
#  '1300 block of clayton',
#  'failure to stop at stop sign',
#  '13th and valencia',
#  '13th/ trainor',
#  '13th/harrison',
#  'potrero 25',
#  'potrero 26th',
#  'florida st / 17th st',
#  'florida st / 18th st',
#  'florida st / 22nd st',
#  'florida st / 24th st',
#  'florida st / division st',
#  '14th/ harrison',
#  '14th/ valencia',
#  'quesada keith',
#  'quesada/3rd',
#  '1500 block of  fulton',
#  'r-1 outbound at t1 turnaround',
#  'r-1 outbound',
#  'r1 inbound under itb',
#  'rac, kiss and fly',
#  'ran a stop a sign',
#  'ran a stop sign',
#  'fowler ave / sydney way',
#  'red light',
#  'rent a car center',
#  'ricon /bryant',
#  'riding bike on sidewalk.',
#  '15th/ valencia',
#  '15th/valencia',
#  'randolph/head',
#  'rear plate',
#  '1600 block of ingalls',
#  '1600 block of powell',
#  'rey and heritage',
#  'russia/la grande',
#  'fulton st/6th st',
#  's. mcdonnell @ firehouse #3',
#  'fail to obey sign',
#  'fail to obey signs',
#  'fail to obey traffic sign',
#  'fail to signal',
#  'fail to stop at two separate red lights',
#  'failed to stop at a red light',
#  'fairfax and ironwood',
#  's. mcdonnell at cng',
#  's. mcdonnell at south field',
#  's. mcdonnell at s.field checkpoints',
#  'firehouse 3',
#  'flagged down regarding restraining order violation',
#  '16th weise',
#  '16th/kirkham',
#  '16th/spencer',
#  '1700 balboa',
#  'folsom/stoneman',
#  '1700 block of  mckinnon',
#  'font holloway',
#  'francisco/stockton',
#  'franconia/brewster',
#  'san jose ave / geneva ave',
#  'fulton @ webster',
#  'fulton/ 4th ave',
#  'fulton/19th',
#  '17th/dearborn',
#  'funston @ clement',
#  '1800 block of eddy',
#  '1800 block of hayes',
#  '1800 block of market',
#  'futon  & 30th ave',
#  '1800 block of mission',
#  'sfia arrivals level at courtyard 3 next to terminal 2',
#  'sfia domestic term ll door 2',
#  'sfia domestic parking level 4',
#  'sfia itb ul door 1',
#  'sfia itb upper level door 4',
#  'sfia itb upper level door 6',
#  'sfia lower domestic door 4',
#  'sfia lower domestic t1',
#  'sfia lower domestic t2',
#  'sfia lower itb',
#  'sfia lower t1 and courtyard 2',
#  'sfia r-1 inbound',
#  'sfia r-1 inbound at departures',
#  'sfia r-1 outbound',
#  '18th st/280 nb z 25th ind',
#  'sfia r1 inbound - terminal 1 arrivals level @ door 13',
#  'sfia terminal 3 door 1 arrivals level',
#  'sfia trillium cng lot',
#  'sfia upper itb door 4',
#  'sfia upper domestic door 6',
#  'sfia upper itb door #1',
#  'sfia upper itb door #3',
#  'sfia upper itb door #4',
#  'sfia upper itb door #5',
#  'sfia upper itb door 1',
#  'sfia upper itb door 2',
#  'sfia upper itb door 3',
#  'sfia upper itb door 5',
#  '18th and douglas',
#  'geary franklin',
#  '18th/south van',
#  '1900 block of lombard',
#  '192012978',
#  'silver and thomas',
#  'geary/polk',
#  'silver/hamilton',
#  'so mcconnell rd at trillium cng lot exit',
#  'so mcdonald rd at trillium cng lot entrance',
#  'spine rd at trillium cng lot exit',
#  '19th ave and js',
#  '19th ave/holloway',
#  '19th ave/santiago',
#  '19th b4 js',
#  '19th chur h',
#  '19th sanchez',
#  'stockton st & market st',
#  '19th/ alabama',
#  '19th/ guerrero',
#  'stockton st / market st',
#  'subj was double parked in the transit only lane',
#  'subject was driving vehicle with no headlights at darkness',
#  '200 block beach',
#  'subject was driving vehicle with no license plate lamp',
#  'subject was drving vehicle with expired registration',
#  'subject was parked in front of fire hydrant',
#  'grove street',
#  '200 block of minerva',
#  '200 blk italy st',
#  'gt. bus staging lot',
#  '200 block of 2nd st',
#  'garfield/juniper serra',
#  '200 block of shipley',
#  '200 block of tenth street',
#  'geary @ funston',
#  '20th @ irving',
#  'geneva/brookdale',
#  'santos/brookdale',
#  'sawyer / visitation',
#  '20th/irving',
#  'gough and grove',
#  '21453a cvc',
#  'gough lombard',
#  '21950a cvc',
#  'greta highway at judah',
#  'grove not larkin',
#  'gt staging area',
#  'guttenburg',
#  'southern',
#  'spine rd @ cell phone lot',
#  'spine road @ cell phone lot',
#  'spine road by cell phone lot',
#  '21st/ church',
#  '21st/ south van',
#  '2200 block of market',
#  '22100a cvc',
#  '22102 cvc violation',
#  '22102 cvc violence',
#  '22450 wb euclid, did not stop nor slow',
#  'steiner/eddy',
#  'harvard st / felton st',
#  'stockton/columbus',
#  '22nd ave/santiago',
#  'stop sign violation',
#  'stop sign',
#  'subject was in a vehicle with expired registration.',
#  'hawthorne / howard',
#  '22nd/ south van',
#  '22nd/balboa',
#  'sunrise / malosi',
#  'sunset / lincoln',
#  '23123.5',
#  '23123.5 cvc',
#  'headlight out',
#  '23rd st / pennsylvania ave',
#  't # 3, lower domestic roadway, at door #01, sfia',
#  't # 3, upper roadway, door #12, sfia',
#  '23rd st and elizabeth st',
#  '23rd/ hampshire',
#  'howard / hathrone',
#  '23rd/ svn',
#  '23rd/treat',
#  '2400 block harrison',
#  '2400 block of diamond',
#  'tennessee st / 25th st',
#  'texas st & 25th st',
#  'tnc 3 and moc',
#  '2500 block of diamond',
#  'haight and waller.',
#  'harrington/mission',
#  'harrison 10th',
#  '25th/bartlett',
#  'trillium cng lot',
#  'harrison dore',
#  'trillium cng lot exit',
#  '25th/connecticut',
#  '25th/kirkham',
#  'harrison/ 17th',
#  'harrison/22nd st.',
#  'harrison/8th st',
#  'hayes/polk',
#  'headlamp was out',
#  'heather st. @ euclid',
#  'holloway 19th',
#  'taxi lot a/b 3, lvl 1',
#  'holloway cardenas',
#  'holloway cervantes',
#  'holloway stratford',
#  'holloway varela',
#  'holloway/ miramar',
#  'holloway/lee',
#  'holloway/tapia',
#  'taylor and green',
#  'hooper/7th',
#  '2700 block of gough',
#  '27th/vicente',
#  'tennessee/20th',
#  'terminal 1',
#  'terminal 1 arrivals.',
#  'terminal 3',
#  'terry francis and 16th st',
#  '280nb at cesar chavez',
#  '2863 mission',
#  'howard hawthorne',
#  'howard mission',
#  'the subject vehicle was stopped on hudson avenue with the nearest cross street of phelps avenue',
#  'howard/hawthrone',
#  'howard/hawthorne',
#  'tinted windows',
#  'hudson/ardath',
#  'to end 4th',
#  'toland and barnevard',
#  'tompkins/peralta',
#  'townsend 3rd',
#  'townsend clyde',
#  'townsend n 3rd',
#  'illegal left turn',
#  'townsend n 4th',
#  'townsend n lusk',
#  'illinois st / 19th st',
#  'traffic stop',
#  'indiana st / 19th st',
#  'trumble/congdon',
#  '2nd@mission',
#  '300 block of turk',
#  '300 block of grant st',
#  '300 blk of turk',
#  'u turn in a business dist.',
#  'u/l itb center island',
#  'u/l itb door 5',
#  'ul itb',
#  '300 block of  townsend',
#  'ul itb  door 4',
#  '300 block of 2nd st',
#  'ul itb , door 2',
#  'ul itb , door 4',
#  'innes and ingalls',
#  'ul itb , door 5',
#  'ul itb door 2',
#  'ul itb door 3',
#  'ul itb door 4',
#  'ul itb zone 14',
#  'ul itb, door #4',
#  '300 block of mission',
#  'ul itb, door #5',
#  'ul itb, door 2',
#  'ul itb, door 3',
#  'ul itb, door 4',
#  '300 block of townsend',
#  'ul itb, door 5',
#  'ul itb,door 1',
#  'ul itb,door 2',
#  'ul itb,door 3',
#  'ul itb,door 4',
#  'ul itb,door 5',
#  'ul t1 door 10',
#  'ul t1 door 11',
#  '300 buckingham',
#  'ul t1,door 3',
#  'ul t3 door 12',
#  'ul t3 door 13',
#  'ul t3 door.6',
#  'ul t3, door 7',
#  '3000 block of mission',
#  'itb # g door #5 outer curbside',
#  'itb bart platform',
#  'itb center island zone 12',
#  'itb door 3',
#  'itb door 4 center island',
#  'itb departures level door 3 curbside',
#  'itb garage',
#  'itb r1 outbound',
#  'itb upper door 5',
#  'itb upper level door 5',
#  'itb upper level curbside door #3',
#  'itb upper door 1',
#  'itb upper door 6',
#  'itb, departures, door 1',
#  'itb, departures, zone 12',
#  'improper right turn',
#  'improper turn',
#  'indiana st. / 22nd st.',
#  '3100 block for franklin st',
#  '3100 block of  army st.',
#  'international departures level',
#  'unit block of jansen',
#  'international terminal',
#  'upper itb',
#  'upper itb curbside',
#  'upper itb door #4',
#  'upper itb door 2',
#  'upper itb door 5',
#  'upper itb door 3',
#  'upper itb door 4',
#  'italy and london',
#  'upper itb door 6',
#  'upper level itb departures',
#  'upper level itb, door 3',
#  '3300 18th',
#  'upper level itb, door 4',
#  '3300 block 18th',
#  'upper level itb, door 5',
#  'upper level, itb door 1',
#  'upper t1',
#  'ulitb, door 5',
#  'ulloa @ 36th',
#  'union & mason',
#  '341 somerset',
#  'union/powell',
#  'unit block of castro',
#  'unit block of belcher',
#  'unit block of mcallister',
#  'unit block of sequoia',
#  'unit block columbus',
#  'unit block freelon',
#  'unit block of 7th st',
#  'unit block of cayuga st',
#  'unit block of osceola',
#  '3600 blk fulton',
#  'unit block of potrero',
#  'united employee parking/tnc lot 3',
#  'unsafe load',
#  'upper domestic / t2',
#  'upper it be sfia',
#  'upper itb center island',
#  'upper itb door #2',
#  'upper itb door 2 curbside',
#  'upper itb door 3 curbside',
#  'upper itb door 4 curbside',
#  'upper itb door 4 curbiside',
#  'upper level , t2, door 1',
#  'upper level itb',
#  'upper level itb center island',
#  '3700 block of cesar chavez',
#  'upper level itb door 3',
#  'upper level t1 and t2 connector',
#  'upper level terminal 1 door 11',
#  'upper level terminal 3 door 7',
#  'upper level of terminal 3, door 2',
#  'upper t1  /  door 4',
#  'upper t1 door 8 sfia',
#  'upper t2',
#  'upper t2 door 2 sfia',
#  'upper t3 door 13 sfia',
#  'upper terminal 2',
#  'upper level itb door 5',
#  'upper level t3 door 9',
#  'upper level itb departures door 3',
#  'upper level itb, door 2',
#  'upper level itb,door 2',
#  'upper level itb,door 4',
#  '38300 cvc violation',
#  'upper level terminal 1, door 7',
#  'upper level terminal 3, door 3',
#  'upper t3, door 2',
#  'upper t3, door 3',
#  '38th ave / john f kennedy',
#  '3rd street and !9th street',
#  'jackson/cherry',
#  'jansen / columbus',
#  'jennings/cargo',
#  'jessie st e and mission',
#  'virginia ave / winfield st',
#  '3rd/quesada',
#  '3rd/townsend',
#  '3rd/wallace',
#  '400 block of galvez',
#  'jordan/euclid',
#  '400 block of 8th street',
#  '400 block of townsend',
#  '400 block of gonzalez',
#  '400 block of hayes',
#  '400 manzil',
#  'judson/ acadia',
#  '4000 block of mission',
#  '4000a cvc',
#  'valencia/sycamore',
#  '43rd and lincoln ave',
#  'vehicle eastbound frederick street does not come to a complete full stop behind the limit line at willard street.',
#  'vehicle failed to yield to a pedestrian in a crosswalk',
#  '453 bush',
#  'visitacion/mansell',
#  'kansas/17th st',
#  'king/5th st',
#  '4th / mission',
#  '4th ave/ lincoln',
#  'kirkham/la playa',
#  'kirkwood and dominartory',
#  'kirkwood/rankin',
#  'kiska & riordan',
#  'known subject driving on suspended license',
#  'l/l itb shared ride zone',
#  '4th at balboa',
#  '4th clara',
#  '500 block of fulton',
#  '500 john shelly',
#  '500 blk stevenson',
#  'washington @ davis',
#  '500 block castro',
#  'washington at powell',
#  'lane st / wallace ave',
#  '500 block of  frederick',
#  'lane st/wallace av',
#  '500 block of innes street',
#  '500 block of mission',
#  '500 block of larkin',
#  '500 block vallejo',
#  'williams & reddy',
#  'williams & apollo',
#  'winston stonecrest',
#  'xxxxx',
#  '5324 mission',
#  'york/26th',
#  'lawton/19th',
#  'advisement',
#  'albion and valencia',
#  'anza at 14',
#  '5@harrison',
#  'asdffff',
#  '5th @ jessie',
#  'balbo and 4th ave',
#  'basic speed',
#  'bay and polk',
#  '5th at clement',
#  'blank row',
#  'lincoln/10th',
#  '5th n berry',
#  'linden st / buchanan st',
#  'broadway and post',
#  'll itb taxi stand',
#  'll itb,door 3',
#  'brotherhood/arch',
#  '5th/anza',
#  '5th/clement',
#  '600   stevenson',
#  'capitol/demonte',
#  '600 block of polk',
#  'capp at 16',
#  '600 block of mission',
#  'capp/adair',
#  '600 bk. west field rd',
#  'carroll/ingalls',
#  '600 block of  frederick',
#  'lot cc',
#  '600 block of fulton',
#  'castro and hartford',
#  'lower level itb shared ride vans zone',
#  '600 block of larch',
#  '600 block of market',
#  '600 block of broadway',
#  '600 block of mcallister',
#  'cell phone lot',
#  '600 block of morse',
#  'cell phone while driving',
#  'cellphone lot',
#  '600 block sanone',
#  '600-block of howard',
#  'channel/4th',
#  'chavez / hampshire',
#  'city hall',
#  'clarendon / olympic',
#  'clarendon at ulloa',
#  'lake @ 2nd ave',
#  'lake @ 6th ave',
#  'lake @ 8th ave',
#  'clayton and cole',
#  'clement at 10',
#  'clement at 5th',
#  '6th ave/hugo',
#  'cng trillium pumps',
#  'cng trillium pumps exit',
#  'cole  /  clayton',
#  'congdon/maynard',
#  'cross over double line',
#  'larkin and pacific',
#  'diamond/surrey',
#  'disobey signs',
#  'lexington/18th',
#  'driver made an illegal turn and the vehicle had expired registration.',
#  'driver was driving a vehicle with only one working stop lamp.',
#  'driver was using his phone while driving',
#  'driving in transit lane',
#  'driving in transit only lnae',
#  'driving in wrong lane',
#  'driving with non operable brake light',
#  '6th/clement',
#  'drum at washington',
#  'lincoln blvd/7th ave',
#  'lincoln st/mlk',
#  '7 dwight',
#  '70 block of mission',
#  '700  arrel',
#  'eddy / frederick',
#  'll t3, door 9',
#  '700 block of kirkwood',
#  '700 black union',
#  '700 blk vallejo',
#  'lombard at chestnut',
#  'lot cc, limo lot',
#  'expired registration',
#  '700 block of mission',
#  'lower domestic roadway  /  t2',
#  'failed to stop at stop sign',
#  'lower itb taxi stand',
#  'failure to comply with posted sign',
#  '700 block of townsend',
#  'lower itb center island, sfia',
#  'failure to comply with posted sign and improper use roadways and walks',
#  'lower level itb door 3',
#  'fell @ laguna',
#  'lower level terminal 2, door 3',
#  '700 block of market',
#  'lower terminal 1 door 8 sfia',
#  '7100 block of funston st',
#  'lower garage a entrance sfia',
#  'lower level terminal 1',
#  'firehouse 3',
#  'florida st / 24th st',
#  '7th ave/lincoln ave',
#  'font/cambon',
#  'font/juniper serra',
#  'font/tapia',
#  '7th ave/lincoln',
#  'fulton at 10',
#  'gar bl/ arguello bl',
#  'geary   /   ofarrell',
#  'geary  /  ofarrell',
#  '800 market',
#  'market/octavia',
#  '800 block masonic',
#  '800 block of  mission',
#  '800 block of howard',
#  '800 block of la playa',
#  '800 block of mission',
#  'grant and battery',
#  '800 block of cayuga',
#  'mason',
#  'grant at pacific',
#  "800 block of o''''ferril",
#  '800 mission',
#  'hearst/edna',
#  'howard @ 4th',
#  'howard @ 9th',
#  '8th and jessie',
#  '8th folsom',
#  '8th harrison',
#  '8th jarrison',
#  'illegal turn',
#  'illegal u turn',
#  'illegal u-turn',
#  'impeding the flow',
#  'improper left turn at the intersection',
#  '8th/irving',
#  '900 blk harrison',
#  '900 block mission',
#  'irving and frederick',
#  'irving at 15',
#  'irving at 16',
#  'irving at 17',
#  'irving at 20',
#  '900 blk grant',
#  'itb upper door #2',
#  '900 block harrison',
#  '900 block market',
#  'jessie @ 3rd',
#  '900 block of  bryant',
#  '900 block of  larkin',
#  '900 block of mission',
#  'mint/ mission',
#  'juniper serra @ stonecrest',
#  '9@market',
#  'mission and arleta',
#  '9th ti st & avenue d',
#  'la sale & newcomb',
#  'la sale / ingalls',
#  '9th street and avenue b',
#  'lakeview/brighton',
#  'lakeview/granada',
#  'alana and executive parkway',
#  'left turn against posted signal',
#  'll itb center island, shuttle stand',
#  'lot cc',
#  'lower level itb, door 2',
#  'lower level limo and taxi stand',
#  'made a left on no left turn',
#  'market/ 10',
#  'market/jones',
#  'market@5',
#  'markets street',
#  'anza/wood',
#  'airport blvd and costco',
#  'mission and 3th',
#  'alison/cross',
#  'mandell st/kirkwood ave',
#  'mansell/girard',
#  'ashbury/page',
#  'athens/france',
#  'markat front',
#  'marker and powell',
#  'market street',
#  'mission@4',
#  'mission@5',
#  'motorist had one headlight not working properly',
#  'multiple stop sign violations',
#  'n/b s mcd rd to s/b to s mcd rd',
#  'bannan pl / green st',
#  'n/b s. mcd rd',
#  'n/b south mcd rd',
#  'n/b south mcd rd/gate 7',
#  'market front',
#  'nb 280 / 18th street',
#  'nb powell wb sutter',
#  'nb s mcd rd',
#  'battery, market',
#  'no front plate',
#  'no parking',
#  'no turn on red',
#  'mason / taylor',
#  'mason and green',
#  'northbound s mcd rd',
#  'northbound s mcd rd, between firehouse 3 and gate 7',
#  'masonic/waller',
#  'oak@pierce',
#  'oakdale / loomis',
#  'oakdale and baldwin',
#  'obey sign',
#  'ocean @ 19th',
#  'ocean @ 20th',
#  'ocean and js',
#  'ocean and junper sera',
#  'officers believed the plate of the vehicle did not match the make of the vehicle',
#  'otsego / ruddard',
#  'outside cellphone lot',
#  'pacific / grant',
#  'pacific/grant',
#  'mcdonnell and tnc 1',
#  'palou/jennings',
#  'mendell/galvez st',
#  'ped fail to yield',
#  'pine sdt',
#  'mission / ocean',
#  'polk @ fern',
#  'polk at green',
#  'potrero and ceasar chavez',
#  'quint newcomb',
#  'r1 outbound from level 5 garage',
#  'randoplh.ramsell',
#  'randoplh/victoria',
#  'registration expired, improper plates',
#  'registration tabs',
#  'rental car center, center island',
#  'right turn no signal',
#  'brtant / 2nd',
#  's/b n mcd rd',
#  's/b south mcd rd',
#  'sagamore/capitol',
#  'bryant/ricon',
#  'bryant/rincon',
#  'mission/france',
#  'mission/niagara',
#  'sideshows / tint',
#  'mission/trumbull',
#  'mission/washburn',
#  'baden/joost',
#  'balboa @ 24nd',
#  'speed',
#  'speeding',
#  'st charles/alemany',
#  'balboa/22nd',
#  'balboa/24th',
#  'balboa/5th',
#  'bartlett/ 23rd',
#  'n/a..',
#  'bay & jones',
#  'stolen vehicle',
#  'stopped in roadway',
#  'subj ran in front of patrol vehicle  /  started hitting it',
#  'subject made a illegal left turn',
#  'subject made an illegal left turn',
#  'subject made an illegal right turn',
#  'subject made an illegal uturn',
#  'subject made an improper right turn',
#  'subject was driving a vehicle with no license plates',
#  'sunset blvd/ vincente',
#  'bay at webster',
#  'sunset/ocean',
#  'sunset/ulloa',
#  'talking on cell phone while driving',
#  'n/b s mcd rd/north of gate 7',
#  'taylor and beach',
#  'bayshore/schrewin',
#  'terminal #3 curbside',
#  'tinted windows violation',
#  'traffic stop for traffic violation',
#  'traffic violation',
#  'treat/17th',
#  'trilium lot',
#  'berry 4th',
#  'beverly/halloway',
#  'bosworth/elk',
#  'brake light',
#  'turned against posted sign',
#  'u turn biz dist',
#  'u turn in bus district',
#  'ul itb center island shuttle stand',
#  'ul itb departures',
#  'ul itb door 1',
#  'union/powelll',
#  'brannan gilbert',
#  'unit blk 6th st',
#  'unit blk quincy',
#  'unit block lincoln avenue',
#  'brazil and la grande',
#  'unit block of 2nd st',
#  'unit block of 6th street',
#  'brazil/la grande',
#  'unit block of 8th st',
#  'unit block of 8th street',
#  'broadway  /  union',
#  'unit block of albion st',
#  'unit block of osceola st',
#  'unit block of sixth street',
#  'unit block of taylor street',
#  'unsafe left turn',
#  'upper itb departures',
#  'upper itb door #5',
#  'upper itb curbside door 4',
#  'upper itb t3 door 12',
#  'upper itb, center island, door 3',
#  'upper itb, door 2',
#  'upper itb, door 3',
#  'upper itb, door 4',
#  'upper itb, door 5',
#  'upper level domestic t5',
#  'upper level itb , door 2',
#  'upper level itb center island, zone 11',
#  'upper level itb departures door 1',
#  'upper level itb door 4',
#  'upper level itb, 280 to 380 split',
#  'upper level itb, center island zone 11',
#  'bryant 2nd',
#  'upper level itb, center island, door 2',
#  'upper level itb, door 1',
#  'upper level itb, door 6',
#  'upper level itb, lane #1',
#  'upper level itb, zone 11',
#  'upper level t2',
#  'upper level t2, door 4',
#  'upper level t2-t3',
#  'upper level t3, door 3',
#  'upper level terminal 1, door 10',
#  'upper level terminal 3, door 10',
#  'upper level, itb door 4',
#  'upper level, door 4',
#  'upper level, itb door 2',
#  'upper level, itb door 3',
#  'northpoint/ powell',
#  'upper level, itb door 5',
#  'upper level, t3 door 3',
#  'upper level. itb door 5',
#  'napolean / jerrold',
#  'vanness and cedar',
#  'vanness at bay two vehicles second vehicle was white female',
#  'vehicle did not have plates',
#  'newcomb/keith',
#  'newhall/lasalle',
#  'vehicle had exp reg',
#  'ney/congdon',
#  'vehicle had broken tail light, driver made unsafe lane change.',
#  'no left',
#  'vehicle was driving in reserve bus area',
#  'no left turn violation',
#  'vicenet at 32',
#  'no lights',
#  'vicente at 18',
#  'vicente at 28',
#  'no plates',
#  'vicente at 32',
#  'no rear plate',
#  'bryant and sterling',
#  'noe/20th',
#  'vidal/garces',
#  'violate ped',
#  'visitation- britton',
#  'waller/potomac',
#  'buchanan/fell',
#  'woodside/hernandez',
#  'north point taylor',
#  'burrows- gambier',
#  'ocean/lakewood',
#  'carver st / chapman st',
#  'cc / valencia',
#  'cell phone lot',
#  'channel / 04th st',
#  'clement & 5th',
#  'cng trillium',
#  'cng trillium pumps',
#  'cng trillium lot',
#  'corbin pl / 17th st',
#  'cell phone without hands free',
#  'cellphone lot',
#  'cesar chavez/ evans',
#  'clara 5th',
#  'clay at waverley',
#  'clement @ funston',
#  'clement at 5th',
#  'clement/26th',
#  'clement/3rd',
#  'clement/funston',
#  'cole /oak st',
#  'college']

# %%
for i in SFPD_converted[SFPD_converted['neighborhood'] is None]['location']:
